# %%
import os
os.environ['OPENBLAS_NUM_THREADS'] = '16'
import numpy as np

# %%
# need to change
embedding_path = '../gcl/embeddings/GRACE_20251014/ent_embed.npz'
embeddings = np.load(embedding_path)['embeddings']
