# %%
from _plot import plot_tsne
import numpy as np

# %%
# need to change
embedding_path = '../gcl/embeddings/gcl_20251014/ent_embed.npz'

# %%
embeddings = np.load(embedding_path)['embeddings']
plot_tsne(embeddings, type_filters=['gene/protein', 'disease'])
