# %%
import pandas as pd
import json
import random

# %%
new_triples_dmd = pd.read_csv('../approved_triples_latest.csv')
print(new_triples_dmd.shape[0])
new_triples_dmd.head()
# Out:
# 333
#                      relation   x_type            y_type         x_id  \
# 0  disease_phenotype_positive  disease  effect/phenotype  kg4rd:10679
# 1     anatomy_protein_present  anatomy      gene/protein  kg4rd:15230
# 2             disease_protein  disease      gene/protein  kg4rd:10679
# 3             disease_protein  disease      gene/protein  kg4rd:10679
# 4  disease_phenotype_positive  disease  effect/phenotype  kg4rd:10679
#
#          y_id                               uid             x_preferred_name  \
# 0  kg4rd:1249  :40400011:8cxiHTfHEbuMJ5cudTfhtn  duchenne muscular dystrophy
# 1  kg4rd:1756  :40368879:KSNJHm4UB6yne29TsVe6b2          dorsal vessel heart
# 2  kg4rd:1431  :40366239:52d5FmoktMw9P8H9yRsyEL  duchenne muscular dystrophy
# 3  kg4rd:9780  :40361216:QW9DbX3U4yc8iP2ugNLKfx  duchenne muscular dystrophy
# 4  kg4rd:3287  :40359883:JrogmgpD3XR4BMnqfQWogW  duchenne muscular dystrophy
#
#                           y_preferred_name  x_preferred_name_score  \
# 0                  intellectual disability                  1000.0
# 1                                      dmd                  1000.0
# 2                                       cs                  1000.0
# 3                                   piezo1                  1000.0
# 4  abnormality of mitochondrial metabolism                  1000.0
#
#    y_preferred_name_score
# 0                  1000.0
# 1                  1000.0
# 2                  1000.0
# 3                  1000.0
# 4                  1000.0

# %%
nodes = pd.read_csv('../../../kge_origin/nodes.csv')
print(nodes.shape[0])
nodes.head()
# Out:
# 151321
#    node_index      node_id     node_type node_name node_source
# 0           0    kg4rd:381  gene/protein      ARF5        NCBI
# 1           1   kg4rd:4074  gene/protein      M6PR        NCBI
# 2           2   kg4rd:2288  gene/protein     FKBP4        NCBI
# 3           3  kg4rd:56603  gene/protein   CYP26B1        NCBI
# 4           4  kg4rd:55471  gene/protein   NDUFAF7        NCBI

# %%
nodes_d = nodes.drop_duplicates(['node_id', 'node_type'], keep='first')
nodes_d.shape[0]
# Out:
# 151112

# %%
df = pd.merge(new_triples_dmd, nodes_d, left_on=['x_id', 'x_type'], right_on=['node_id', 'node_type'], how='left').rename(columns={'node_index': 'x_index'}).get(
    ['relation', 'x_index', 'y_id', 'y_type']
).astype({'x_index': int}).astype({'x_index': str})

print(df.shape[0])

df = pd.merge(df, nodes_d, left_on=['y_id', 'y_type'], right_on=['node_id', 'node_type'], how='left').rename(columns={'node_index': 'y_index'}).get(
    ['relation', 'x_index', 'y_index']
).astype({'y_index': int}).astype({'y_index': str})

print(df.shape[0])
df.head()
# Out:
# 333
# 333
#                      relation x_index y_index
# 0  disease_phenotype_positive   27017   29854
# 1     anatomy_protein_present  103463    9016
# 2             disease_protein   27017    7812
# 3             disease_protein   27017    4785
# 4  disease_phenotype_positive   27017   32707

# %%
df['relation'].value_counts()
# Out:
# relation
# disease_protein               133
# disease_phenotype_positive    115
# bioprocess_protein             25
# disease_disease                20
# phenotype_protein              17
# anatomy_protein_present        11
# phenotype_phenotype             6
# anatomy_protein_absent          5
# cellcomp_protein                1
# Name: count, dtype: int64

# %%
df_reverse = df.query('relation != "disease_disease" and relation != "phenotype_phenotype"')
df_reverse = df_reverse.rename(columns={'x_index': 'y_index', 'y_index': 'x_index'})
df_reverse.shape[0]
# Out:
# 307

# %%
df_reverse
# Out:
#                        relation y_index x_index
# 0    disease_phenotype_positive   27017   29854
# 1       anatomy_protein_present  103463    9016
# 2               disease_protein   27017    7812
# 3               disease_protein   27017    4785
# 4    disease_phenotype_positive   27017   32707
# ..                          ...     ...     ...
# 328          bioprocess_protein   67142    2241
# 329          bioprocess_protein   67142    8107
# 330          bioprocess_protein   67142   13265
# 331          bioprocess_protein   67142    2884
# 332          bioprocess_protein   67142    8204
#
# [307 rows x 3 columns]

# %%
df = pd.concat([df, df_reverse], ignore_index=True)
df.shape[0]
# Out:
# 640

# %%
df['relation'].value_counts()
# Out:
# relation
# disease_protein               266
# disease_phenotype_positive    230
# bioprocess_protein             50
# phenotype_protein              34
# anatomy_protein_present        22
# disease_disease                20
# anatomy_protein_absent         10
# phenotype_phenotype             6
# cellcomp_protein                2
# Name: count, dtype: int64

# %%
edges = pd.read_csv('../../../kge_origin/edges.csv')
print(edges.shape[0])
edges.head()
# Out:
# 14641692
#           relation display_relation  x_index  y_index
# 0  protein_protein              ppi        0     1898
# 1  protein_protein              ppi        0      769
# 2  protein_protein              ppi        0    15031
# 3  protein_protein              ppi        0     2385
# 4  protein_protein              ppi        0     4981

# %%
edges_new = pd.concat([
    edges,
    df
], ignore_index=True)
print(edges_new.shape[0])
edges_new.tail()
# Out:
# 14642332
#                     relation display_relation x_index y_index
# 14642327  bioprocess_protein              NaN    2241   67142
# 14642328  bioprocess_protein              NaN    8107   67142
# 14642329  bioprocess_protein              NaN   13265   67142
# 14642330  bioprocess_protein              NaN    2884   67142
# 14642331  bioprocess_protein              NaN    8204   67142

# %%
with open('./data/entity2id.txt', 'w') as f:
    f.write(f'{len(nodes)}\n')
    for _, row in nodes.iterrows():
        f.write(f'{row["node_name"]}:{row["node_type"]}\t{row["node_index"]}\n')

# %%
relations = edges_new.drop_duplicates(subset=['relation'])['relation'].to_list()
relation2id = {relation: i for i, relation in enumerate(relations)}

with open('./data/relation2id.txt', 'w') as f:
    f.write(f'{len(relations)}\n')
    for k, v in relation2id.items():
        f.write(f'{k}\t{v}\n')

# %%
edges_new['rela_id'] = edges_new['relation'].apply(lambda x: relation2id[x])
edges_new = edges_new[['x_index', 'y_index', 'rela_id']]
data = list(edges_new.itertuples(index=False, name=None))
random.shuffle(data)
data[:10]
# Out:
# [(102728, 114503, 28),
#  (19633, 19695, 5),
#  (25802, 20386, 5),
#  (25956, 22996, 5),
#  (15876, 94900, 28),
#  (100976, 82887, 28),
#  (98142, 14916, 28),
#  (94684, 13284, 28),
#  (96972, 116584, 28),
#  (29328, 22999, 5)]

# %%
with open('./data/all2id.txt', 'w') as f:
    f.write(f'{len(data)}\n')
    for x, y, r in data:
        f.write(f'{x} {y} {r}\n')

# %%
edges['rela_id'] = edges['relation'].apply(lambda x: relation2id[x])
edges = edges[['x_index', 'y_index', 'rela_id']]
data_base = list(edges.itertuples(index=False, name=None))
random.shuffle(data_base)

with open('./data/all2id_base.txt', 'w') as f:
    f.write(f'{len(data_base)}\n')
    for x, y, r in data_base:
        f.write(f'{x} {y} {r}\n')

# %%
train_size = int(len(data) * 0.9)
valid_size = int(len(data) * 0.05)
test_size = len(data) - train_size - valid_size

print('train size: ', train_size)
print('valid size: ', valid_size)
print('test size: ', test_size)

train_data = data[:train_size]
valid_data = data[train_size:train_size+valid_size]
test_data = data[train_size+valid_size:]
# Out:
# train size:  13178098
# valid size:  732116
# test size:  732118

# %%
with open('./data/train2id.txt', 'w') as f:
    f.write(f'{len(train_data)}\n')
    for x, y, r in train_data:
        f.write(f'{x} {y} {r}\n')

with open('./data/valid2id.txt', 'w') as f:
    f.write(f'{len(valid_data)}\n')
    for x, y, r in valid_data:
        f.write(f'{x} {y} {r}\n')

with open('./data/test2id.txt', 'w') as f:
    f.write(f'{len(test_data)}\n')
    for x, y, r in test_data:
        f.write(f'{x} {y} {r}\n')
