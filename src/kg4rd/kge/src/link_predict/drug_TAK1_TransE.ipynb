# %%
from unike.module.model import TransE
import yaml
import sys

sys.path.extend(['.', '..'])

from q import link, drug_ent_indexs, drug_protein_rel_index, tak1_ent_index, add_id
# Out:
# /home/wangtao/src/kg4rd/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:51: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
# need to change
config_path = '../../config/transe_gpus_20250910.yaml'
checkpoint_path = '../../checkpoints/transe_gpus_20250910-200.pth'

# %%
with open(config_path, 'r') as f:
	config = yaml.load(f, Loader=yaml.FullLoader)

model = TransE(
	ent_tol = 121649,
	rel_tol = 22,
	dim = config['dim'], 
	p_norm = config['p_norm'], 
	norm_flag = config['norm_flag']
)
model.load_checkpoint(checkpoint_path)

# %%
df = link.link(
    drug_ent_indexs,
    [drug_protein_rel_index],
    [tak1_ent_index],
    model, 'cuda:0'
)
df = add_id(df)
df.to_csv('../../link_result/drug_tak1_transe.csv', index=False)
