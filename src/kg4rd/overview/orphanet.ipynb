# %%
from q import primekg_orphanets
from q import primekg_edges_orphanets

# %%
len(primekg_orphanets)
# Out:
# 6881

# %%
primekg_edges_orphanets.query('relation in ["indication", "off-label use"] and x_type == "drug" and y_type == "disease"')['x_index'].unique().shape[0]
# Out:
# 777

# %%
primekg_edges_orphanets.query('relation in ["indication", "off-label use"] and x_type == "drug" and y_type == "disease"').shape[0]
# 只计算单向关系 否则是6672
# Out:
# 3336

# %%
primekg_edges_orphanets['relation'].value_counts()
# Out:
# relation
# disease_phenotype_positive    187638
# disease_protein                65170
# disease_disease                36430
# contraindication               10510
# indication                      4726
# off-label use                   1946
# disease_phenotype_negative      1140
# exposure_disease                 600
# Name: count, dtype: int64

# %%
from q import primekg_nodes
from q import primekg_edges

# %%
primekg_nodes.query('node_type == "disease"').shape
# Out:
# (17080, 5)

# %%
primekg_edges.query('relation in ["indication", "off-label use"] and x_type == "drug" and y_type == "disease"')['x_index'].unique().shape[0]
# Out:
# 1855

# %%
primekg_edges['relation'].value_counts()
# Out:
# relation
# anatomy_protein_present       3036406
# drug_drug                     2672628
# protein_protein                642150
# disease_phenotype_positive     300634
# bioprocess_protein             289610
# cellcomp_protein               166804
# disease_protein                160822
# molfunc_protein                139060
# drug_effect                    129568
# bioprocess_bioprocess          105772
# pathway_protein                 85292
# disease_disease                 64388
# contraindication                61350
# drug_protein                    51306
# anatomy_protein_absent          39774
# phenotype_phenotype             37472
# anatomy_anatomy                 28064
# molfunc_molfunc                 27148
# indication                      18776
# cellcomp_cellcomp                9690
# phenotype_protein                6660
# off-label use                    5136
# pathway_pathway                  5070
# exposure_disease                 4608
# ...

# %%
from q import orphanets
from q import edges_orphanets

# %%
len(orphanets)
# Out:
# 9065

# %%
edges_orphanets.query('relation in ["indication", "off-label use"] and x_type == "drug" and y_type == "disease"')['x_index'].unique().shape[0]
# Out:
# 920

# %%
edges_orphanets.query('relation in ["indication", "off-label use"] and x_type == "drug" and y_type == "disease"').shape[0]
# Out:
# 2370

# %%
edges_orphanets['relation'].value_counts()
# Out:
# relation
# disease_phenotype_positive    151140
# disease_disease                30990
# disease_protein                22640
# contraindication                3170
# indication                      1803
# disease_phenotype_negative       608
# off-label use                    567
# Name: count, dtype: int64
