# %% [markdown]
# # PrimeKG

# %%
import pandas as pd
import sys

sys.path.append('.')

from q import primekg_nodes
from q import primekg_edges
from q import plot_degree_distribution
from q import primekg_orphanets
from q import primekg_edges_orphanets

# %%
print("实体总数量:", primekg_nodes.shape[0])
print("不同类型实体数量:", primekg_nodes['node_type'].value_counts())
# Out:
# 实体总数量: 129375
# 不同类型实体数量: node_type
# biological_process    28642
# gene/protein          27671
# disease               17080
# effect/phenotype      15311
# anatomy               14035
# molecular_function    11169
# drug                   7957
# cellular_component     4176
# pathway                2516
# exposure                818
# Name: count, dtype: int64

# %%
total_relations = primekg_edges.shape[0]
print("关系总数量:", total_relations)
relation_counts = primekg_edges['relation'].value_counts()
relation_percent = (relation_counts / total_relations * 100).round(3)
relation_summary = pd.DataFrame({
    '关系数量': relation_counts,
    '占比(%)': relation_percent
})
print("不同类型关系数量及占比:")
print(relation_summary)
# Out:
# 关系总数量: 8100498
# 不同类型关系数量及占比:
#                                关系数量   占比(%)
# relation
# anatomy_protein_present     3036406  37.484
# drug_drug                   2672628  32.993
# protein_protein              642150   7.927
# disease_phenotype_positive   300634   3.711
# bioprocess_protein           289610   3.575
# cellcomp_protein             166804   2.059
# disease_protein              160822   1.985
# molfunc_protein              139060   1.717
# drug_effect                  129568   1.600
# bioprocess_bioprocess        105772   1.306
# pathway_protein               85292   1.053
# disease_disease               64388   0.795
# contraindication              61350   0.757
# drug_protein                  51306   0.633
# anatomy_protein_absent        39774   0.491
# phenotype_phenotype           37472   0.463
# anatomy_anatomy               28064   0.346
# molfunc_molfunc               27148   0.335
# indication                    18776   0.232
# cellcomp_cellcomp              9690   0.120
# phenotype_protein              6660   0.082
# off-label use                  5136   0.063
# pathway_pathway                5070   0.063
# exposure_disease               4608   0.057
# exposure_exposure              4140   0.051
# exposure_bioprocess            3250   0.040
# exposure_protein               2424   0.030
# disease_phenotype_negative     2386   0.029
# exposure_molfunc                 90   0.001
# exposure_cellcomp                20   0.000
